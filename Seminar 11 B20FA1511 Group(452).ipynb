# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Даалгавар 1a
data = [12,10.12,1.5,2.3,6.4,7.73]
label = ['Python','Java','PHP','Javascript','C#','C++']
explode = (0,0.2,0.3,0.3,0,0)
plt.pie(data, explode=explode, labels=label, autopct='%1.1f%%',shadow=True, startangle=90)
plt.title(label='TIOBE:Popularity Of Programming Languages Worldwide, Dec 2021')
# Out:
# Text(0.5, 1.0, 'TIOBE:Popularity Of Programming Languages Worldwide, Dec 2021')

# %%
#Даалгавар 1b
data = {
    'Python': 12,
    'Java': 10.12,
    'C++':7.73,
    'C#':6.4,
    'Javascript':2.3,
    'PHP':1.5 
} 
fig = plt.figure(figsize = (10, 5))
 
plt.bar(courses, values, color =['red','black','green','blue','yellow','maroon'] ,width = 0.4)
 
plt.xlabel("Languages ")
plt.ylabel("Popularity")
plt.title("TIOBE:Popularity Of Programming Languages Worldwide, Dec 2021")
plt.show()

# %%
#Даалгавар 2a
data = [30.21, 17.82, 9.16, 7.53, 6.82, 5.84, 3.81]
label = ['Python','Java','Javascript','C#','C++','PHP','R']
explode = (0.1,0,0,0,0,0.2,0.2)
plt.pie(data, explode=explode, labels=label, autopct='%1.1f%%', shadow=True, startangle=90)
plt.title(label='PYPL:Popularity Of Programming Languages Worldwide, Dec 2021')
# Out:
# Text(0.5, 1.0, 'PYPL:Popularity Of Programming Languages Worldwide, Dec 2021')

# %%
#Даалгавар 2b
data = {
    'Python': 30.21,
    'Java': 17.82,
    'Javascript':9.16,
    'C#':7.53,
    'C++':6.82,
    'PHP':5.84,
    'R':3.81
} 
fig = plt.figure(figsize = (10, 5))
 
plt.bar(courses, values, color =['maroon','red','yellow','blue','green','maroon'] ,width = 0.4)
plt.xlabel("Languages ")
plt.ylabel("Popularity")
plt.title("PYPL:Popularity Of Programming Languages Worldwide, Dec 2021")
plt.show()
